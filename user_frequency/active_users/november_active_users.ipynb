# %%
#!/usr/bin/python3
'''
Author: Shamugia Genadi
Project: User Frequency Calculator
Description: Program takes csv files which are twitter scraper captures and counts the number of occurances of each username. 
'''
#Importing used librarires
import csv
import sys
import ast
import os
import glob

def main():

    path = r'C:\Users\m216126\Documents\capstoneStuff\twitterCapture\captures\november'      # use your path
    files = os.listdir(path)
    print(files)

    # files_csv = [i for i in files if i.endswith('.csv')]
    usernameList = [] #List for all the usernames
    #Open and read the csv file.
    for f in files:
        if f.endswith('.csv'):
            print('Reading file ' + f + '. Please wait...')
            print(path+'\\'+str(f))
            with open(path+'\\'+str(f),encoding="utf8") as csv_file: 
                csv_reader = csv.reader(csv_file, delimiter=',')
                line_count = 0
                print(csv_reader)
             
                for row in csv_reader:
                    try:
                        cell = ast.literal_eval(row[4])
                        username = cell['user_mentions'][0]['screen_name'] #grab the username
                        usernameList.append(username)
                        line_count += 1
                    except: #Exception for unusual cases
                        line_count +=1
                        pass

    
    CountFrequency(usernameList) 

def CountFrequency(my_list): 
    # Creating an empty dictionary  
    freq = {} 
    for item in my_list: 
        if (item in freq): 
            freq[item] += 1
        else: 
            freq[item] = 1

    #order the Dictionary by Value in descending order
    sorted_orders = sorted(freq.items(), key=lambda x:x[1],reverse=True)



    print(sorted_orders)
main()
# Out:
# ['resultsElection2020-11-1.csv', 'resultsElection2020-11-10.csv', 'resultsElection2020-11-2.csv', 'resultsElection2020-11-3.csv', 'resultsElection2020-11-4.csv', 'resultsElection2020-11-5.csv', 'resultsElection2020-11-6.csv', 'resultsElection2020-11-7.csv', 'resultsElection2020-11-8.csv', 'resultsElection2020-11-9.csv']
# Reading file resultsElection2020-11-1.csv. Please wait...
# C:\Users\m216126\Documents\capstoneStuff\twitterCapture\captures\november\resultsElection2020-11-1.csv
# <_csv.reader object at 0x0000029AEC651F40>
# Reading file resultsElection2020-11-10.csv. Please wait...
# C:\Users\m216126\Documents\capstoneStuff\twitterCapture\captures\november\resultsElection2020-11-10.csv
# <_csv.reader object at 0x0000029AEC520C40>
# Reading file resultsElection2020-11-2.csv. Please wait...
# C:\Users\m216126\Documents\capstoneStuff\twitterCapture\captures\november\resultsElection2020-11-2.csv
# <_csv.reader object at 0x0000029AEC5912E0>
# Reading file resultsElection2020-11-3.csv. Please wait...
# C:\Users\m216126\Documents\capstoneStuff\twitterCapture\captures\november\resultsElection2020-11-3.csv
# <_csv.reader object at 0x0000029AEC591460>
# Reading file resultsElection2020-11-4.csv. Please wait...
# C:\Users\m216126\Documents\capstoneStuff\twitterCapture\captures\november\resultsElection2020-11-4.csv
# <_csv.reader object at 0x0000029AEC4F2F40>
# Reading file resultsElection2020-11-5.csv. Please wait...
# C:\Users\m216126\Documents\capstoneStuff\twitterCapture\captures\november\resultsElection2020-11-5.csv
# <_csv.reader object at 0x0000029AEC651F40>
# Reading file resultsElection2020-11-6.csv. Please wait...
# C:\Users\m216126\Documents\capstoneStuff\twitterCapture\captures\november\resultsElection2020-11-6.csv
# <_csv.reader object at 0x0000029AEC4F2F40>
# Reading file resultsElection2020-11-7.csv. Please wait...
# C:\Users\m216126\Documents\capstoneStuff\twitterCapture\captures\november\resultsElection2020-11-7.csv
# <_csv.reader object at 0x0000029AEC608700>
# Reading file resultsElection2020-11-8.csv. Please wait...
# C:\Users\m216126\Documents\capstoneStuff\twitterCapture\captures\november\resultsElection2020-11-8.csv
# <_csv.reader object at 0x0000029AEC520C40>
# Reading file resultsElection2020-11-9.csv. Please wait...
# C:\Users\m216126\Documents\capstoneStuff\twitterCapture\captures\november\resultsElection2020-11-9.csv
# <_csv.reader object at 0x0000029AEC4F2F40>
# [('realDonaldTrump', 4207), ('JoeBiden', 2047), ('BTS_twt', 1078), ('BernieSanders', 758), ('KamalaHarris', 647), ('mmpadellan', 641), ('kylegriffin1', 542), ('mygtrivias', 494), ('ProjectLincoln', 473), ('donwinslow', 442), ('marceelias', 380), ('DonaldJTrumpJr', 376), ('JackPosobiec', 375), ('charliekirk11', 373), ('MeidasTouch', 357), ('btsvotingorg', 347), ('kayleighmcenany', 334), ('RBReich', 329), ('ddale8', 327), ('funder', 322), ('TeamTrump', 316), ('benshapiro', 310), ('RealJamesWoods', 309), ('marklevinshow', 297), ('dbongino', 294), ('Amy_Siskind', 294), ('BarackObama', 288), ('thehill', 282), ('CNN', 279), ('HKrassenstein', 276), ('atrupar', 266), ('HillaryClinton', 257), ('SteveSchmidtSES', 253), ('TheRickWilson', 239), ('965TDY', 238), ('joncoopertweets', 234), ('zaynmalik', 233), ('YouTube', 232), ('TomFitton', 224), ('lvlalachi', 222), ('DineshDSouza', 219), ('PeteButtigieg', 206), ('GeorgeTakei', 204), ('IngrahamAngle', 203), ('jaketapper', 200), ('sarahcpr', 199), ('nytimes', 198), ('ABC', 196), ('nowthisnews', 196), ('AOC', 190), ('RexChapman', 186), ('briantylercohen', 186), ('w_terrence', 185), ('JoyAnnReid', 184), ('TrumpWarRoom', 183), ('itsJeffTiedrich', 182), ('MSNBC', 176), ('PalmerReport', 173), ('Yamiche', 172), ('drewstreaming', 158), ('NBCNews', 157), ('salty_ashley', 157), ('Mike_Pence', 156), ('NateSilver538', 155), ('RyanAFournier', 152), ('ScottPresler', 151), ('AriBerman', 151), ('DanRather', 149), ('schizoanalytic', 149), ('weareoneEXO', 147), ('ladygaga', 142), ('Redistrict', 142), ('EricTrump', 142), ('DC_Draino', 142), ('Cernovich', 140), ('Acosta', 139), ('softsadsatan', 139), ('JamesOKeefeIII', 138), ('cbozy', 137), ('Al_Sanchino', 137), ('thebradfordfile', 136), ('robreiner', 135), ('FLOTUS', 135), ('RealCandaceO', 134), ('Malloryy4059', 134), ('therecount', 133), ('Jim_Jordan', 133), ('FoxNews', 131), ('RichardGrenell', 131), ('Aspiringt_', 131), ('MaryLTrump', 130), ('kaitlancollins', 130), ('marcorubio', 129), ('choi_bts2', 128), ('Mikel_Jollett', 128), ('MichelleObama', 126), ('GOP', 126), ('jonfavs', 126), ('hsdaily', 125), ('seanhannity', 125), ('yungfundipp', 123), ('ewarren', 121), ('spectatorindex', 121), ('NPR', 120), ('Wizard_Predicts', 120), ('ScottAdamsSays', 119), ('TeaPainUSA', 118), ('MollyJongFast', 117), ('washingtonpost', 117), ('ARMYTEAMIID', 117), ('tribelaw', 116), ('TheRickyDavila', 114), ('BreeNewsome', 114), ('AP', 114), ('RudyGiuliani', 113), ('BillKristol', 112), ('CBSNews', 112), ('ACLU', 112), ('stillgray', 112), ('TheRightMelissa', 112), ('nypost', 108), ('BreitbartNews', 108), ('AngrierWHStaff', 108), ('brianklaas', 107), ('SethAbramson', 106), ('andimcam', 106), ('jeonbubbles', 105), ('jadevvictoria', 104), ('DiamondandSilk', 102), ('TheDailyShow', 102), ('GrahamAllen_1', 102), ('BeschlossDC', 101), ('chrislhayes', 101), ('Votingnation13', 100), ('SebGorka', 99), ('jemelehill', 99), ('IvankaTrump', 98), ('McFaul', 98), ('PpollingNumbers', 97), ('CNNPolitics', 95), ('GOPLeader', 95), ('TayIorVoteStats', 95), ('kylenabecker', 95), ('TheOnion', 95), ('CherylStrayed', 95), ('jennycohn1', 94), ('kurteichenwald', 94), ('mHow250', 93), ('robbystarbuck', 92), ('DavidCornDC', 91), ('DrBiden', 91), ('EXOPublicity', 90), ('YourAnonCentral', 90), ('andreagibson', 90), ('Transition46', 89), ('Reuters', 88), ('minsugacheonye', 88), ('JennaEllisEsq', 88), ('mehdirhasan', 88), ('TomiLahren', 88), ('AdamParkhomenko', 86), ('BTSChartDailyx', 86), ('AshaRangappa_', 86), ('TheRealHoarse', 86), ('JoeNBC', 86), ('ReallyAmerican1', 85), ('paulsperry_', 85), ('2cooI4skull', 85), ('eugenegu', 85), ('nprpolitics', 85), ('Lrihendry', 84), ('mwheat14', 83), ('Leonce', 83), ('Zendaya', 83), ('rihanna', 82), ('h3ystephanie_', 82), ('newsmax', 81), ('JoyceWhiteVance', 80), ('gtconway3d', 80), ('taylorswift13', 80), ('USPoliticsPoll', 80), ('waltshaub', 79), ('JRubinBlogger', 79), ('OhOEvie', 79), ('MZHemingway', 78), ('politico', 78), ('TheDemCoalition', 78), ('ChuckCallesto', 78), (' ...
