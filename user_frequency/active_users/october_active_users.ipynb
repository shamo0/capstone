# %%
#!/usr/bin/python3
'''
Author: Shamugia Genadi
Project: User Frequency Calculator
Description: Program takes csv files which are twitter scraper captures and counts the number of occurances of each username. 
'''
#Importing used librarires
import csv
import sys
import ast
import os
import glob

def main():

    path = r'C:\Users\m216126\Documents\capstoneStuff\twitterCapture\captures\october'      # use your path
    files = os.listdir(path)

    # files_csv = [i for i in files if i.endswith('.csv')]
    usernameList = [] #List for all the usernames
    #Open and read the csv file.
    for f in files:
        if f.endswith('.csv'):
            print('Reading file ' + f + '. Please wait...')
            with open(path+'\\'+str(f),encoding="utf8") as csv_file: 
                csv_reader = csv.reader(csv_file, delimiter=',')
                line_count = 0
             
                for row in csv_reader:
                    try:
                        cell = ast.literal_eval(row[4])
                        username = cell['user_mentions'][0]['screen_name'] #grab the username
                        usernameList.append(username)
                        line_count += 1
                    except: #Exception for unusual cases
                        line_count +=1
                        pass

    
    CountFrequency(usernameList) 

def CountFrequency(my_list): 
    # Creating an empty dictionary  
    freq = {} 
    for item in my_list: 
        if (item in freq): 
            freq[item] += 1
        else: 
            freq[item] = 1

    #order the Dictionary by Value in descending order
    sorted_orders = sorted(freq.items(), key=lambda x:x[1],reverse=True)



    print(sorted_orders)
main()
# Out:
# Reading file resultsElection2020-10-10.csv. Please wait...
# Reading file resultsElection2020-10-12.csv. Please wait...
# Reading file resultsElection2020-10-13.csv. Please wait...
# Reading file resultsElection2020-10-14.csv. Please wait...
# Reading file resultsElection2020-10-15.csv. Please wait...
# Reading file resultsElection2020-10-16.csv. Please wait...
# Reading file resultsElection2020-10-18.csv. Please wait...
# Reading file resultsElection2020-10-19.csv. Please wait...
# Reading file resultsElection2020-10-20.csv. Please wait...
# Reading file resultsElection2020-10-21.csv. Please wait...
# Reading file resultsElection2020-10-22.csv. Please wait...
# Reading file resultsElection2020-10-23.csv. Please wait...
# Reading file resultsElection2020-10-24.csv. Please wait...
# Reading file resultsElection2020-10-25.csv. Please wait...
# Reading file resultsElection2020-10-26.csv. Please wait...
# Reading file resultsElection2020-10-27.csv. Please wait...
# Reading file resultsElection2020-10-28.csv. Please wait...
# Reading file resultsElection2020-10-29.csv. Please wait...
# Reading file resultsElection2020-10-30.csv. Please wait...
# Reading file resultsElection2020-10-4.csv. Please wait...
# Reading file resultsElection2020-10-5.csv. Please wait...
# Reading file resultsElection2020-10-6.csv. Please wait...
# Reading file resultsElection2020-10-7.csv. Please wait...
# Reading file resultsElection2020-10-8.csv. Please wait...
# Reading file resultsElection2020-10-9.csv. Please wait...
# [('realDonaldTrump', 12658), ('JoeBiden', 6825), ('ProjectLincoln', 4057), ('mmpadellan', 3208), ('kylegriffin1', 3169), ('funder', 3028), ('DonaldJTrumpJr', 2645), ('MeidasTouch', 2560), ('RealJamesWoods', 2290), ('JackPosobiec', 2041), ('TrumpWarRoom', 2033), ('KamalaHarris', 1964), ('ddale8', 1921), ('donwinslow', 1917), ('HKrassenstein', 1894), ('charliekirk11', 1890), ('atrupar', 1703), ('BTS_twt', 1656), ('dbongino', 1629), ('BernieSanders', 1530), ('paulsperry_', 1390), ('thehill', 1368), ('Amy_Siskind', 1243), ('joncoopertweets', 1225), ('DanRather', 1103), ('marklevinshow', 1082), ('MSNBC', 1081), ('SethAbramson', 1070), ('RyanAFournier', 1069), ('sarahcpr', 1061), ('RBReich', 1056), ('CNN', 1047), ('GeorgeTakei', 1039), ('DineshDSouza', 1030), ('YouTube', 994), ('CaslerNoel', 975), ('TeamTrump', 966), ('thebradfordfile', 963), ('maddow', 951), ('eugenegu', 877), ('nytimes', 842), ('PalmerReport', 839), ('BillKristol', 811), ('IngrahamAngle', 805), ('kayleighmcenany', 781), ('Mike_Pence', 773), ('ReallyAmerican1', 772), ('Jim_Jordan', 757), ('DrEricDing', 754), ('ChuckCallesto', 752), ('catturd2', 742), ('PeteButtigieg', 741), ('JoyceWhiteVance', 717), ('seanhannity', 682), ('TheRickWilson', 677), ('benshapiro', 672), ('JRubinBlogger', 667), ('RudyGiuliani', 664), ('TeaPainUSA', 659), ('RepsForBiden', 655), ('Acosta', 655), ('EricTrump', 652), ('TheRealHoarse', 642), ('btsvotingorg', 640), ('BarackObama', 631), ('GOP', 630), ('glennkirschner2', 620), ('RexChapman', 620), ('bbylayaaa', 619), ('AngrierWHStaff', 617), ('itsJeffTiedrich', 603), ('NBCNews', 591), ('SenSchumer', 589), ('tribelaw', 588), ('washingtonpost', 582), ('FoxNews', 581), ('mygtrivias', 581), ('RepAdamSchiff', 563), ('seanmdav', 561), ('MZHemingway', 554), ('nowthisnews', 548), ('SteveSchmidtSES', 548), ('GOPChairwoman', 540), ('curtisisbooger', 537), ('jonfavs', 533), ('joelockhart', 531), ('Yamiche', 529), ('Jillbiden46', 524), ('chipfranklin', 519), ('BreitbartNews', 514), ('jaketapper', 501), ('newtgingrich', 497), ('waltshaub', 491), ('AriBerman', 489), ('ABC', 488), ('RealCandaceO', 488), ('AdamParkhomenko', 485), ('DavidCornDC', 483), ('clairecmc', 479), ('kaitlancollins', 477), ('briantylercohen', 472), ('Strandjunker', 465), ('RichardGrenell', 463), ('robertjdenault', 457), ('maggieNYT', 455), ('DailyCaller', 450), ('BcraigV', 450), ('RealRLimbaugh', 447), ('MollyJongFast', 441), ('kirstiealley', 425), ('chrislhayes', 421), ('mkraju', 420), ('ananavarro', 415), ('robreiner', 415), ('Scaramucci', 415), ('sloaneloges_', 410), ('JuddLegum', 395), ('StevenBeschloss', 393), ('NateSilver538', 392), ('RepMattGaetz', 390), ('CNNPolitics', 389), ('B52Malmet', 388), ('politvidchannel', 385), ('HillaryClinton', 379), ('nypost', 376), ('Lrihendry', 374), ('weareoneEXO', 371), ('TomFitton', 369), ('meiselasb', 367), ('CHIZMAGA', 366), ('RVAT2020', 364), ('AOC', 359), ('NPR', 357), ('taebokkiii', 357), ('WalshFreedom', 356), ('jimsciutto', 355), ('MilesTaylorUSA', 353), ('murray_nyc', 353), ('CREWcrew', 349), ('davidmweissman', 349), ('CBSNews', 348), ('thedailybeast', 348), ('AP', 348), ('thomaskaine5', 346), ('DrPhillipsMD', 343), ('realTuckFrumper', 338), ('stillgray', 336), ('WhiteHouse', 333), ('TheDemCoalition', 332), ('DrDenaGrayson', 330), ('ThePubliusUSA', 328), ('NatashaBertrand', 327), ('robbystarbuck', 323), ('bennyjohnson', 321), ('gtconway3d', 320), ('JasonMillerinDC', 318), ('choi_bts2', 318), ('ScottAdamsSays', 316), ('tedcruz', 315), ('Timcast', 314), ('kurteichenwald', 310), ('TuckerCarlson', 310), ('brhodes', 308), ('MajorPatriot', 306), ('keithboykin', 305), ('JoyAnnReid', 302), ('politico', 302), ('matthewjdowd', 300), ('LawEnforceToday', 299), ('SteveGuest', 298), ('TheBabylonBee', 296), ('DWUhlfelderLaw', 288), ('therecount', 287), ('965TDY', 286), ('realHeatherD', 285), ('SenSanders', 283), ('w_terrence', 281), ('SenKamalaHarris', 281), ('AliVelshi', 280), ('amyklobuchar', 278), ('GeoffRBennett', 277), ('Redistrict', 275), ('abigai ...
