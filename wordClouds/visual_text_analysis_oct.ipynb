# %%
'''Word Cloud visual image analysis of almost half a million tweets from october regarding the 2020 elections'''
# Out:
# 'visual image analysis of almost half a million tweets from september regarding the 2020 elections'

# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk
import glob
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud
import json
from collections import Counter
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\m216126\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
path = r'C:\Users\m216126\Documents\capstoneStuff\twitterCapture\captures\october'      # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))     # advisable to use os.path.join as this makes concatenation OS independent
li = []
for file in all_files:
    df = pd.read_csv(file, index_col = None, header=0)
    li.append(df)

# %%
# Naming the columns

for i in range(len(li)):
    li[i].columns = ['Date','id','tweet','tweet_info','metadata']

# %%
## Concatenate all the files into a single dataset

frames = []

for i in range(len(li)):
    frames.append(li[i])
tweet_dataset = pd.concat(frames)

# %%
tweet_dataset.shape
# Out:
# (458048, 5)

# %%
tweet_dataset.tail()
# Out:
#                       Date                   id  \
# 15260  2020-10-09 19:59:38  1314656788881440769
# 15261  2020-10-09 19:59:38  1314656788877381632
# 15262  2020-10-09 19:59:38  1314656788877377536
# 15263  2020-10-09 19:59:38  1314656788856352768
# 15264  2020-10-09 19:59:38  1314656788839620611
#
#                                                    tweet  \
# 15260  b'RT @RAICESTEXAS: The Trump administration en...
# 15261  b'RT @RudyGiuliani: Joe Biden: "You\xe2\x80\x9...
# 15262  b'@mlow29 No idea, but the hope was by the end...
# 15263  b'RT @AdamWollner: The Biden campaign is curre...
# 15264  b"@ProjectLincoln Has anyone checked Trump's a...
#
#                                               tweet_info  \
# 15260  User(_api=<tweepy.api.API object at 0x10c9aab9...
# 15261  User(_api=<tweepy.api.API object at 0x10c9aab9...
# 15262  User(_api=<tweepy.api.API object at 0x10c9aab9...
# 15263  User(_api=<tweepy.api.API object at 0x10c9aab9...
# 15264  User(_api=<tweepy.api.API object at 0x10c9aab9...
#
#                                                 metadata
# 15260  {'hashtags': [], 'symbols': [], 'user_mentions...
# 15261  {'hashtags': [], 'symbols': [], 'user_mentions...
# 15262  {'hashtags': [], 'symbols': [], 'user_mentions...
# 15263  {'hashtags': [], 'symbols': [], 'user_mentions...
# 15264  {'hashtags': [], 'symbols': [], 'user_mentions...

# %%
#Cleaning Tweets

corpus = []
for i in range(0, int(tweet_dataset.shape[0])):
#     tweet = str(tweet_dataset['tweet'][i])
    try:
        tweet = re.sub('[^a-zA-Z0-9]', ' ', tweet_dataset['tweet'][i])
        tweet = tweet.lower()
        tweet = re.sub("b'", '', tweet)
        tweet = re.sub('https', '', tweet)
        tweet = tweet.split()
    #     ps = PorterStemmer()
    #     tweet = [ps.stem(word) for word in tweet if not word in set(stopwords.words('english'))]
        for j in range(len(tweet)):
            if len(tweet[j]) <= 3:
                tweet[j] = ''
            elif (len(tweet[j]) == 4) and (tweet[j][0]=='x'):
                tweet[j] = ''
        tweet = ' '.join(tweet)
        corpus.append(tweet)
    except:
        continue

# %%
#Visualization

#Word Cloud
all_words = ' '.join([text for text in corpus])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()
